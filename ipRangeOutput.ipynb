# %%
import ipaddress

# %%
firstIp = ipaddress.IPv4Address('10.0.1.70')
lastIp = ipaddress.IPv4Address('10.0.1.170')
for ip_int in range(int(firstIp), int(lastIp)):
    print(ipaddress.IPv4Address(ip_int))
# Out:
# 10.0.1.70
# 10.0.1.71
# 10.0.1.72
# 10.0.1.73
# 10.0.1.74
# 10.0.1.75
# 10.0.1.76
# 10.0.1.77
# 10.0.1.78
# 10.0.1.79
# 10.0.1.80
# 10.0.1.81
# 10.0.1.82
# 10.0.1.83
# 10.0.1.84
# 10.0.1.85
# 10.0.1.86
# 10.0.1.87
# 10.0.1.88
# 10.0.1.89
# 10.0.1.90
# 10.0.1.91
# 10.0.1.92
# 10.0.1.93
# 10.0.1.94
# 10.0.1.95
# 10.0.1.96
# 10.0.1.97
# 10.0.1.98
# 10.0.1.99
# 10.0.1.100
# 10.0.1.101
# 10.0.1.102
# 10.0.1.103
# 10.0.1.104
# 10.0.1.105
# 10.0.1.106
# 10.0.1.107
# 10.0.1.108
# 10.0.1.109
# 10.0.1.110
# 10.0.1.111
# 10.0.1.112
# 10.0.1.113
# 10.0.1.114
# 10.0.1.115
# 10.0.1.116
# 10.0.1.117
# 10.0.1.118
# 10.0.1.119
# 10.0.1.120
# 10.0.1.121
# 10.0.1.122
# 10.0.1.123
# 10.0.1.124
# 10.0.1.125
# 10.0.1.126
# 10.0.1.127
# 10.0.1.128
# 10.0.1.129
# 10.0.1.130
# 10.0.1.131
# 10.0.1.132
# 10.0.1.133
# 10.0.1.134
# 10.0.1.135
# 10.0.1.136
# 10.0.1.137
# 10.0.1.138
# 10.0.1.139
# 10.0.1.140
# 10.0.1.141
# 10.0.1.142
# 10.0.1.143
# 10.0.1.144
# 10.0.1.145
# 10.0.1.146
# 10.0.1.147
# 10.0.1.148
# ...
